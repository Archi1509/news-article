# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.preprocessing import LabelEncoder

import warnings

warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('merged_data.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0  India’s overall exports in July this year esti...
# 1           Gold up by Rs 95; Silver climbs Rs 160\n
# 2  Oil steadies as investors weigh concerns about...
# 3  Sensex ends 79 points higher to settle at 65,4...
# 4       Rupee closes at Rs 82.94 against US dollar\n
#
#                                              Article  Category
# 0  India’s overall exports in July this year are ...  Business
# 1  Gold prices today (14 August 2023) rose by 95 ...  Business
# 2  Oil prices steadied today (14 August 2023) as ...  Business
# 3  Key domestic benchmark indices ended flat toda...  Business
# 4  In the forex market, the rupee closed at 82 ru...  Business

# %%
df.columns
# Out:
# Index(['Title', 'Article', 'Category'], dtype='object')

# %%
df.shape
# Out:
# (7136, 3)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (6113, 3)

# %%
df
# Out:
#                                                   Title  \
# 0     India’s overall exports in July this year esti...
# 1              Gold up by Rs 95; Silver climbs Rs 160\n
# 2     Oil steadies as investors weigh concerns about...
# 3     Sensex ends 79 points higher to settle at 65,4...
# 4          Rupee closes at Rs 82.94 against US dollar\n
# ...                                                 ...
# 7131  Tata to invest £4 bn to set up 1st gigafactory...
# 7132  Lawsuit accuses Twitter of targeting older sta...
# 7133  Studio shares AI-generated 'South Park' episod...
# 7134  Ensure you don't promote vulgarity, abuse: Tha...
# 7135  20% of Apple's 5-yr user growth to come from I...
#
#                                                 Article    Category
# 0     India’s overall exports in July this year are ...    Business
# 1     Gold prices today (14 August 2023) rose by 95 ...    Business
# 2     Oil prices steadied today (14 August 2023) as ...    Business
# 3     Key domestic benchmark indices ended flat toda...    Business
# 4     In the forex market, the rupee closed at 82 ru...    Business
# ...                                                 ...         ...
# 7131  Tata Group on Wednesday announced its plan to ...  Technology
# 7132  A second lawsuit against Twitter in a week has...  Technology
# 7133  Fable Studios released a fake 'South Park' epi...  Technology
# 7134  Information and Broadcasting Minister Anurag T...  Technology
# 7135  Morgan Stanley analysts on Monday said India c...  Technology
#
# [6113 rows x 3 columns]

# %%
for i, row in df.iterrows():
    soup = BeautifulSoup(row['Title'], 'html.parser')
    if soup.find():
        df.drop(i, inplace=True)

# %%
df.shape
# Out:
# (6020, 3)

# %%
df['Category'].value_counts()
# Out:
# Entertainment    1639
# Politics         1307
# Technology       1098
# Business         1049
# Sports            926
# category            1
# Name: Category, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Title          0
# Article     1208
# Category       0
# dtype: int64

# %%
df = df[df['Category'] != 'category']

# %%
df['Category'].value_counts()
# Out:
# Entertainment    1639
# Politics         1307
# Technology       1098
# Business         1049
# Sports            926
# Name: Category, dtype: int64

# %%
category_counts = df['Category'].value_counts()
plt.bar(category_counts.index, category_counts.values)
plt.title('Article Counts by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
df['Article'] = df['Article'].astype(str)

plt.hist(df['Article'].apply(len), bins=20)
plt.title('Distribution of Article Lengths')
plt.xlabel('Length (characters)')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(x='Category', y=df['Article'].apply(len), data=df)
plt.title('Article Length by Category')
plt.xlabel('Category')
plt.ylabel('Length (characters)')
plt.show()

# %%
df['Title']=df['Title'].str.strip()
df['Title'] = df['Title'].str.replace('\n', '')
df['Title'] = df['Title'].astype(str).apply(lambda x: re.sub(r"short by (.*)$", " ", x))
df['Article']=df['Article'].str.strip()
df['Article'] = df['Article'].str.replace("\n", "")

# %%
df.shape
# Out:
# (6019, 3)

# %%
df['Article'] = df['Article'].fillna('')

df['Text']=df['Title']+" "+df['Article']
df['Text']
# Out:
# 0       India’s overall exports in July this year esti...
# 1       Gold up by Rs 95; Silver climbs Rs 160 Gold pr...
# 2       Oil steadies as investors weigh concerns about...
# 3       Sensex ends 79 points higher to settle at 65,4...
# 4       Rupee closes at Rs 82.94 against US dollar In ...
#                               ...
# 7131    Tata to invest £4 bn to set up 1st gigafactory...
# 7132    Lawsuit accuses Twitter of targeting older sta...
# 7133    Studio shares AI-generated 'South Park' episod...
# 7134    Ensure you don't promote vulgarity, abuse: Tha...
# 7135    20% of Apple's 5-yr user growth to come from I...
# Name: Text, Length: 6019, dtype: object

# %%
df.to_csv('cleaned.csv')

# %%
target_category = df['Category'].unique()
print(target_category)
# Out:
# ['Business' 'Entertainment' 'Politics' 'Sports' 'Technology']

# %%
stop_words = set(stopwords.words('english'))
new_stop_words = ["said","india","nan","added"]
stop_words.update(new_stop_words)
# function to remove stopwords from a string
def remove_stopwords(text):
    filtered_words = [word for word in text.split() if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# apply the function to the 'text' column of the dataframe
#df['text'] = df['text'].apply(remove_stopwords)

# %%
special_chars_pattern = r'[^a-zA-Z0-9\s]'
def remove_special_chars(text):
    return re.sub(special_chars_pattern, '', text)

# %%
def remove_numbers(input_string):
    output_string = re.sub(r'\d+', '', input_string)
    return output_string

# %%
def convert_lower(text):
    return text.lower()

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
def wordcloud_draw(dataset):

    wordcloud = WordCloud(stopwords = stop_words,background_color = 'white',width = 2500, height = 2500).generate(' '.join(dataset))
    plt.figure(1, figsize = (10,7))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
df['Text'] = df['Text'].apply(remove_stopwords)
df['Text'] = df['Text'].apply(remove_special_chars)
df['Text'] = df['Text'].apply(remove_numbers)

df['Text'] = df['Text'].apply(convert_lower)
df['Text'] = df['Text'].apply(lemmatize_words)

# %%
business = df[df['Category'] == 'Business']
business = business['Text']
print("business related words:")

wordcloud_draw(business)
# Out:
# business related words:

# %%
tech = df[df['Category'] == 'Technology']
tech = tech['Text']

print("Technology related words:")

wordcloud_draw(tech)
# Out:
# Technology related words:

# %%
sports = df[df['Category'] == 'Sports']
sports = sports['Text']

print("Sports related words:")

wordcloud_draw(sports)
# Out:
# Sports related words:

# %%
entertainment = df[df['Category'] == 'Entertainment']
entertainment = entertainment['Text']

print("Entertainment related words:")

wordcloud_draw(entertainment)
# Out:
# Entertainment related words:

# %%
politics = df[df['Category'] == 'Politics']
politics = politics['Text']
print("politics related words:")

wordcloud_draw(politics)
# Out:
# politics related words:

# %%
df.head(10)
# Out:
#                                                Title  \
# 0  India’s overall exports in July this year esti...
# 1             Gold up by Rs 95; Silver climbs Rs 160
# 2  Oil steadies as investors weigh concerns about...
# 3   Sensex ends 79 points higher to settle at 65,402
# 4         Rupee closes at Rs 82.94 against US dollar
# 5  Centre to E-auction 50 Lakh MT of wheat and 25...
# 6  Index of Industrial Production growth at 3.7 p...
# 7  Asian stock markets end in red; European Marke...
# 8  Wall Street's main indices end in green as inv...
# 9  Forex Market: Rupee closes at 82.84 against US...
#
#                                              Article  Category  \
# 0  India’s overall exports in July this year are ...  Business
# 1  Gold prices today (14 August 2023) rose by 95 ...  Business
# 2  Oil prices steadied today (14 August 2023) as ...  Business
# 3  Key domestic benchmark indices ended flat toda...  Business
# 4  In the forex market, the rupee closed at 82 ru...  Business
# 5  The Centre has decided to release 50 Lakh Metr...  Business
# 6  The index of industrial production grew by 3.7...  Business
# 7  Asian stock markets today ended in red. China'...  Business
# 8  Wall Street's main indices ended in green yest...  Business
# 9  In the forex market, the rupee closed at 82 ru...  Business
#
#                                                 Text
# 0  india overall export july year estimated billi...
# 1  gold r silver climb r gold price today august ...
# 2  oil steady investor weigh concern china falter...
# 3  sensex end point higher settle key domestic be...
# 4  rupee close r u dollar forex market rupee clos...
# 5  centre eauction lakh mt wheat lmt rice tame in...
# 6  index industrial production growth percent jun...
# 7  asian stock market end red european market als...
# 8  wall street main index end green investor worr...
# 9  forex market rupee close u dollar forex market...

# %%
#declare dependent and independent value

x = df['Text']
y = df['Category']

# %%
#Create and Fit Bag of Words Model
from sklearn.feature_extraction.text import CountVectorizer
x = np.array(df.Text.values)
y = np.array(df.Category.values)
cv = CountVectorizer(max_features = 5000)
x = cv.fit_transform(df.Text).toarray()
print("X.shape = ",x.shape)
print("y.shape = ",y.shape)
# Out:
# X.shape =  (6019, 5000)
# y.shape =  (6019,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0, shuffle = True)
print(len(x_train))
print(len(x_test))
# Out:
# 4213
# 1806

# %%
#create list of model and accuracy dicts
perform_list = [ ]
def run_model(model_name, est_c, est_pnlty):
    mdl=''

    

    if model_name == 'Random Forest':
        mdl = RandomForestClassifier(n_estimators=100 ,criterion='entropy' , random_state=0)

    elif model_name == 'Multinomial Naive Bayes':
        mdl = MultinomialNB(alpha=1.0,fit_prior=True)


    elif model_name == 'Decision Tree Classifier':
        mdl = DecisionTreeClassifier()

    elif model_name == 'Gaussian Naive Bayes':
        mdl = GaussianNB()

    oneVsRest = OneVsRestClassifier(mdl)

    oneVsRest.fit(x_train, y_train)

    y_pred = oneVsRest.predict(x_test)

    # Performance metrics

    accuracy = round(accuracy_score(y_test, y_pred) * 100, 2)

    # Get precision, recall, f1 scores

    precision, recall, f1score, support = score(y_test, y_pred, average='micro')

    print(f'Test Accuracy Score of Basic {model_name}: % {accuracy}')

    print(f'Precision : {precision}')

    print(f'Recall : {recall}')

    print(f'F1-score : {f1score}')

    # Add performance parameters to list

    perform_list.append(dict([('Model', model_name),('Test Accuracy', round(accuracy, 2)),('Precision', round(precision, 2)),('Recall', round(recall, 2)),('F1', round(f1score, 2))]))

# %%
run_model('Random Forest', est_c=None, est_pnlty=None)
# Out:
# Test Accuracy Score of Basic Random Forest: % 84.33
# Precision : 0.8433001107419712
# Recall : 0.8433001107419712
# F1-score : 0.8433001107419712

# %%
run_model('Multinomial Naive Bayes', est_c=None, est_pnlty=None)
# Out:
# Test Accuracy Score of Basic Multinomial Naive Bayes: % 85.99
# Precision : 0.8599114064230343
# Recall : 0.8599114064230343
# F1-score : 0.8599114064230343

# %%
run_model('Decision Tree Classifier', est_c=None, est_pnlty=None)
# Out:
# Test Accuracy Score of Basic Decision Tree Classifier: % 73.59
# Precision : 0.7358803986710963
# Recall : 0.7358803986710963
# F1-score : 0.7358803986710963

# %%
run_model('Gaussian Naive Bayes', est_c=None, est_pnlty=None)
# Out:
# Test Accuracy Score of Basic Gaussian Naive Bayes: % 68.94
# Precision : 0.6893687707641196
# Recall : 0.6893687707641196
# F1-score : 0.6893687707641196

# %%
model_performance = pd.DataFrame(data=perform_list)
model_performance = model_performance[['Model', 'Test Accuracy', 'Precision', 'Recall', 'F1']]
model_performance
# Out:
#                       Model  Test Accuracy  Precision  Recall    F1
# 0             Random Forest          84.33       0.84    0.84  0.84
# 1   Multinomial Naive Bayes          85.99       0.86    0.86  0.86
# 2  Decision Tree Classifier          73.59       0.74    0.74  0.74
# 3      Gaussian Naive Bayes          68.94       0.69    0.69  0.69

# %%
classifier = MultinomialNB();
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

# %%
y_pred1 = cv.transform(['Captains pose with IPL 2023 trophy at Narendra Modi Stadium, Rohit Sharma missing']).toarray()
yy = classifier.predict(y_pred1)
print(yy)
# Out:
# ['Sports']

# %%
y_pred1 = cv.transform(['Which players have been ruled out of IPL 2023 that will begin tomorrow?']).toarray()
yy = classifier.predict(y_pred1)
print(yy)
# Out:
# ['Sports']

# %%
y_pred1 = cv.transform(['Bard not trained using ChatGPT: Google on claims it copied OpenAI']).toarray()
yy = classifier.predict(y_pred1)
print(yy)
# Out:
# ['Technology']

# %%
y_pred1 = cv.transform(['Makers of Prabhas Adipurush unveil new poster on Ram Navami']).toarray()
yy = classifier.predict(y_pred1)
print(yy)
# Out:
# ['Entertainment']

# %%
y_pred1 = cv.transform(['Ex-Haryana CM Bhupinder Hooda joins wrestlers protest in Delhi']).toarray()
yy = classifier.predict(y_pred1)
print(yy)
# Out:
# ['Politics']
